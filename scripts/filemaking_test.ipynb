# %%
import numpy as np
np.set_printoptions(formatter={'float': '{:.3f}'.format})
import tqdm
import matplotlib.pyplot as plt

from datetime import datetime

import pickle
import os

import src.animate_spindle as anisp

from rich.console import Console
from rich.live import Live
from rich.table import Table

import src.spindle_state as ss

# %%
# dir_path = '/Users/emrealca/Documents/Penn/flatiron-microtubules/simulations/data/2D-single-mt-update-200-points-10-mts-50-positions_2026-02-16_16-03-44/'
# dir_path = '/Users/emrealca/Documents/Penn/flatiron-microtubules/simulations/data/2D-single-mt-update-10-points-5-mts-50-positions_2026-02-20_11-03-38'
dir_path = '/Users/emrealca/Documents/Penn/flatiron-microtubules/simulations/data/2D-single-mt-update-10-points-5-mts-50-positions_2026-02-20_11-32-50'

trace_path = os.path.join(dir_path, 'spindle_trace.pkl')
with open(trace_path, "rb") as f:
    spindle_trace = pickle.load(f)

spindle_path = os.path.join(dir_path, 'spindle.pkl')
with open(spindle_path, 'rb') as f:
    spindle_dict = pickle.load(f)

spindle_dict.keys()
# Out:
# dict_keys(['mtoc_pos', 'spindle_state', 'lattice_sites', 'nucleation_rate', 'catastrophe_rate', 'f_pull_0', 'rigidity', 'friction_coefficient', 'growth_rate', 'stall_force', 'drag_factor', 'boundary_radius', 'timestep_size', 'tubulin_budget', 'cytoplasmic_catastrophe_rate', 'dir_path'])

# %%
spindle_from_dict = ss.init_spindle_from_dict(spindle_dict)

spindle_from_dict.spindle_trace = spindle_trace
last_spindle_trace = spindle_trace[list(spindle_trace.keys())[-1]]

spindle_from_dict.set_mtoc_pos(last_spindle_trace['mtoc_pos'])
spindle_from_dict.spindle_state = last_spindle_trace['spindle_state']
spindle_from_dict.current_time = list(spindle_trace.keys())[-1]

spindle_from_dict.single_mt_update_simulation_to_equilibrium(10, initial_cost=last_spindle_trace['cost'],  save=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       7 spindle_from_dict.spindle_state = last_spindle_trace['spindle_state']
#       8 spindle_from_dict.current_time = list(spindle_trace.keys())[-1]
# ---> 10 spindle_from_dict.single_mt_update_simulation_to_equilibrium(10, initial_cost=last_spindle_trace['cost'],  save=True)
#
# File ~/Documents/Penn/flatiron-microtubules/simulations/src/spindle_state.py:597, in Spindle.single_mt_update_simulation_to_equilibrium(self, num_positions, initial_cost, resolution, readout, save)
#     592 attempt_counter += 1
#     593 # print(f'updated spindle state: {self.spindle_state}')
#     594 # print(f'attempt counter: {attempt_counter}')
#     595
#     596 # -- inner loop relax metastate --
# --> 597 meta_traj, meta_boundary_violated = self.relax(resolution=resolution, readout=False,live=live, attempt_number=attempt_counter)
#     599 # compare meta_cost to old_cost
#     600 meta_cost = self.calc_cost()
#
# File ~/Documents/Penn/flatiron-microtubules/simulations/src/spindle_state.py:529, in Spindle.relax(self, resolution, readout, live, attempt_number)
#     522 self.set_mtoc_pos(new_mtoc_pos)
#     523 meta_t += float(self.timestep_size)
#     525 timepoint_data = {
#     526         'spindle_state': self.spindle_state.astype(int),
#     527         'mtoc_pos': self.mtoc_pos,
#     528         'boundary_violated': boundary_violated,
# --> 529         'cost': self.calc_cost(),
#     530     }
#     531 trajectory[meta_t] = timepoint_data
#     533 if readout:
#     534     # initialize table
#
# File ~/Documents/Penn/flatiron-microtubules/simulations/src/spindle_state.py:468, in Spindle.calc_cost(self)
#     465 displacement_cost = np.square(normalize_vecs(self.mtoc_pos)[1]/self.boundary_radius)
#     467 # -- material cost (L_tot - L_max)^2 --
# --> 468 total_mt_length = np.sum(self.mt_norms[self.spindle_state==2]) + np.sum(self.mt_norms[self.spindle_state==4])
#     469 material_cost = np.square((total_mt_length - self.tubulin_budget)/(self.max_total_mt_length - self.tubulin_budget))
#     471 return displacement_cost + material_cost
#
# File /opt/anaconda3/envs/spindle-simulations/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2333, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2327         raise ValueError("Passing `min` or `max` keyword argument when "
#    2328                          "`a_min` and `a_max` are provided is forbidden.")
#    2330     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2333 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2334                     initial=None, where=None):
#    2335     return (a, out)
#    2338 @array_function_dispatch(_sum_dispatcher)
#    2339 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2340         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:
